# %%
import openai
import urllib.request 
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24588\1985842391.py in <module>
#       3 from PIL import Image
#       4 import cv2
# ----> 5 from google.colab.patches import cv2_imshow
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
openai.api_key = "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"

# %%
img_response = openai.Image.create(
    prompt = "lion driving a bus",
    n=1,
    size = "512x512")

# %%
img_response
# Out:
# <OpenAIObject at 0x7f672417a9f0> JSON: {
#   "created": 1671086156,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-1lf47cxTbx7oZU7VMIwTUSas/user-ZtcteQPZ6Tbv6qSi7kcrqmSP/img-Pwsbj7u2cWfbERvuLEoAmVhm.png?st=2022-12-15T05%3A35%3A56Z&se=2022-12-15T07%3A35%3A56Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-15T00%3A03%3A57Z&ske=2022-12-16T00%3A03%3A57Z&sks=b&skv=2021-08-06&sig=8lsHWBWEkABZk4vM%2B1bnxsA29Egz3CA8p/sMCHZlBmg%3D"
#     }
#   ]
# }

# %%
img_url = img_response['data'][0]['url']
img_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-1lf47cxTbx7oZU7VMIwTUSas/user-ZtcteQPZ6Tbv6qSi7kcrqmSP/img-Pwsbj7u2cWfbERvuLEoAmVhm.png?st=2022-12-15T05%3A35%3A56Z&se=2022-12-15T07%3A35%3A56Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-15T00%3A03%3A57Z&ske=2022-12-16T00%3A03%3A57Z&sks=b&skv=2021-08-06&sig=8lsHWBWEkABZk4vM%2B1bnxsA29Egz3CA8p/sMCHZlBmg%3D'

# %%
urllib.request.urlretrieve(img_url, 'img.png')
# Out:
# ('img.png', <http.client.HTTPMessage at 0x7f6723cc16d0>)

# %%
img = cv2.imread('img.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6723CB5E50>

# %%
pip install google.colab
