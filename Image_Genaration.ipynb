# %%
import openai
import urllib.request
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow

# %%
openai.api_key = "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"

# %%
img_response = openai.Image.create(
    
    prompt = 'Dog eating food',
    n = 1,
    size = "512x512")

# %%
img_response
# Out:
# <OpenAIObject at 0x7fbae2f0a090> JSON: {
#   "created": 1675040409,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-1lf47cxTbx7oZU7VMIwTUSas/user-ZtcteQPZ6Tbv6qSi7kcrqmSP/img-UAd5ztmPcQadeltETIS4CixD.png?st=2023-01-30T00%3A00%3A09Z&se=2023-01-30T02%3A00%3A09Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-29T18%3A28%3A08Z&ske=2023-01-30T18%3A28%3A08Z&sks=b&skv=2021-08-06&sig=jMLwKzFNH1%2BElyTDrm0Pp2EkWfE8yYYmw0oiC7BWerA%3D"
#     }
#   ]
# }

# %%
img_response['data'][0]['url']
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-1lf47cxTbx7oZU7VMIwTUSas/user-ZtcteQPZ6Tbv6qSi7kcrqmSP/img-UAd5ztmPcQadeltETIS4CixD.png?st=2023-01-30T00%3A00%3A09Z&se=2023-01-30T02%3A00%3A09Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-29T18%3A28%3A08Z&ske=2023-01-30T18%3A28%3A08Z&sks=b&skv=2021-08-06&sig=jMLwKzFNH1%2BElyTDrm0Pp2EkWfE8yYYmw0oiC7BWerA%3D'

# %%
img_url = img_response['data'][0]['url']

# %%
urllib.request.urlretrieve(img_url, 'img.png')
# Out:
# ('img.png', <http.client.HTTPMessage at 0x7fbad0af2a00>)

# %%
img = cv2.imread("img.png")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FBAD0B50B80>
